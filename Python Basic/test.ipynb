# %%
print(1+1)
# Out:
# 2

# %%
print(4+8)
# Out:
# 12

# %%
name="Krish"
Name="Aarv"

print(name)
print(Name)
# Out:
# Krish
# Aarv

# %%
age=32
if age>30:
    print("Its an Adult")
# Out:
# Its an Adult

# %%
#Single line comments 
print("Hello world")
# Out:
# Hello world

# %%
## line continuation
total=1+2+3+4+5+6+7+8+ \
4+5+6
print(total)
# Out:
# 51

# %%
###Multiple statements on a single line
x=5;y=10;z=x+y

# %%
print(z)
# Out:
# 15

# %%
#understand Semantic in Python
# Variable Assignment
age=32 ## age is an integer 
name="krish" ##name is a string
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type inference 
variable =10
print(type(variable))
# Out:
# <class 'int'>

# %%
variable =10
print(type(variable))
variable="Gautam"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
if True:
    print("Correct Indentation")
    if False:
        print("This print")
    print("This will also print")
print("Outside the If block")
# Out:
# Correct Indentation
# This will also print
# Outside the If block

# %%
# #     VARIABLES:::::
age=23
height =5.5
name="Gautam"
is_student_of_MCA=True

#printing the variables
print("Age: ",age)
print("Height: ", height)
print("Name: ",name)
print("Student of MCA: ",is_student_of_MCA)
# Out:
# Age:  23
# Height:  5.5
# Name:  Gautam
# Student of MCA:  True

# %%
#NAMING CONVENTION
#VARIABLE NAMES SHOULD BE DESCRIPTIVE
# THEY MUST START WITH A LETTER OR '_' AND CONTAINS ALPHABET, NUMBER AND UNDERSCORE
# INVALID VARIABLE LIKE: 
#first-name="krish"
@name="krish"
# Out:
#   Cell In[24], line 6
#     @name="krish"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
name="Gautam"
print(name)
# Out:
# Gautam

# %%
#understanding variables types
#python is dynamically typed, type of a variable is determined at runtime
age=25 #int 
height=5.5 #float
name="gautam" #string
print(type(height))
# Out:
# <class 'float'>

# %%
#Dynamic Typing 
#Python allows the type od a variable to change as the program executes
var=10
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## INPUT
age=int(input("What is your age?"))
print(age,type(age))
# Out:
# 25 <class 'int'>

# %%
num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))
add= num1 + num2
sub= num1 - num2
mul= num1 * num2
div= num1 / num2
print("Sum: ",add)
print("Subtract: ",sub)
print("Multiply: ", mul)
print("division: ", div)
# Out:
# Sum:  30.0
# Subtract:  20.0
# Multiply:  125.0
# division:  5.0

# %%
#DATATYPES
age=35
type(age)
# Out:
# int

# %%
#float
width=65.1
print(width)
print(type(width))
# Out:
# 65.1
# <class 'float'>

# %%
#string
name="Gautam"
print(name)
print(type(name))
# Out:
# Gautam
# <class 'str'>

# %%
#boolean datatype
is_True =True
type(is_True)
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a=10
b=10
a==b
type(a==b)
# Out:
# bool

# %%
##common error
result ="Hello " +"& Welcome"
#string add with string consist a Number
re ="Hello" + str(5)
print(result)
print(re)
# Out:
# Hello & Welcome
# Hello5

# %%
str="Hello"
str.upper
# Out:
# <function str.upper()>

# %%
#operator
num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))
add= num1 + num2
sub= num1 - num2
mul= num1 * num2
div= num1 / num2
print("Sum: ",add)
print("Subtract: ",sub)
print("Multiply: ", mul)
print("division: ", div)
# Out:
# Sum:  567.0
# Subtract:  525.0
# Multiply:  11466.0
# division:  26.0

# %%
a=10
b=5
floor_div_result=a//b  #floor
modules=a%b #modulas operation
exp_result=a**b
print(exp_result)
print(floor_div_result)
print(modules)
# Out:
# 100000
# 2
# 0

# %%
#comparison operator
a=10
b=10
n=14
m=4
print(a==b)#equal
print(a!=b) #not equal to 
print(n>m)#greater than
print(n<m)#less than 
print(n>=m) #greater than equal to
print(n<=m) #less than equal to
# Out:
# True
# False
# True
# False
# True
# False

# %%
#LOGICAL OPERATOR
X=False
Y=True
result= X and Y #AND
print(result)
r1 =X or Y    #OR
print(r1)
r2 =not X
print(r2)
# Out:
# False
# True
# True

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Exponentiation:", a ** b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
# Out:
# Addition: 732.0
# Subtraction: 558.0
# Multiplication: 56115.0
# Division: 7.413793103448276
# Exponentiation: 2.7020611500512813e+244
# Floor Division: 7.0
# Modulus: 36.0
